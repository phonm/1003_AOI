# %% [markdown]
# # 使用NEU-DET練習影像分類，加入模型存取與最重要的資料擴增

# %% [markdown]
# ### 匯入函式庫

# %%
#匯入函式庫，數值矩陣計算numpy，以及畫圖用的matplotlib
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

#匯入
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

# %%
import tensorflow as tf

# %%
#文件搜索的工具
import glob

#這是一個看迴圈進度條的小工具
from tqdm import tqdm 

#匯入電腦視覺的函式庫，作影像讀取和分析使用
import cv2

# %% [markdown]
# ### 讀入一張影像測試與檢視

# %%
#讀一張影像試試

path_name='NEU-DET/train/images/crazing/crazing_1.jpg'
# path_name='chest_xray/train/NORMAL/IM-0117-0001.jpeg'
img = cv2.imread(path_name,cv2.IMREAD_GRAYSCALE)

#cv2.IMREAD_GRAYSCALE 以灰階的格式來讀取圖片。預設值為cv2.IMREAD_COLOR(讀取 RGB 三個 channels)

#其他的讀取方式：(1)matplotlib、(2)PIL
#import matplotlib.image as mpimg
#img = mpimg.imread(path_name)

#from PIL import Image
#img = Image.open(path_name)

# %%
mpl.rcParams['figure.figsize'] = (12,12) #畫布尺寸

# %%
print('img (x_dim, y_dim) and type: ',img.shape, img.dtype)
plt.imshow(img, cmap='gray')
# Out:
# img (x_dim, y_dim) and type:  (200, 200) uint8

# %% [markdown]
# ### 定義訓練資料

# %%
#欲分類的lable與數量
labels_name = os.listdir('./NEU-DET/train/images/')
num_classes = len(labels_name)

# %%
labels_name
# Out:
# ['scratches',
#  'inclusion',
#  'rolled-in_scale',
#  'crazing',
#  'pitted_surface',
#  'patches']

# %%
num_classes
# Out:
# 6

# %%
#建立訓練資料所在的路徑位置與對應的label：(filelist, label)
#label為數字，0代表'NORMAL'、1代表'PNEUMONIA'
filelist = []
label = []
for i in labels_name:
    class_num = labels_name.index(i)
    pathfile = glob.glob('./NEU-DET/train/images/'+str(i)+'/*.jpg')
    
    for p in pathfile:
        filelist.append(p)
        label.append(class_num)

# %%
print('numbers of img:',len(filelist))
# Out:
# numbers of img: 1440

# %%
#影像縮放大小
desired_size = 200

# %%
#定義一個縮放影像(img)至指定大小(desired_size)的函數
#等比例縮小，其他地方補黑邊
def squared(img, desired_size):
    old_size = img.shape[:2]
    ratio = float(desired_size)/max(old_size)
    new_size = tuple([int(x*ratio) for x in old_size])
    img = cv2.resize(img, (new_size[1], new_size[0]))
    delta_w = desired_size - new_size[1]
    delta_h = desired_size - new_size[0]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    color = [0, 0, 0]
    new_img = cv2.copyMakeBorder(img, top, bottom, left, right, cv2.BORDER_CONSTANT,value=color)
    return new_img

# %% [markdown]
# ### 開始讀入影像

# %%
#先宣告一個指定大小的ndarray
all_data = np.zeros((len(filelist),desired_size,desired_size,3), dtype=np.float32)

# %%
#開始讀入影像
for i in tqdm(range(len(filelist))):
    img = cv2.imread(filelist[i], cv2.IMREAD_GRAYSCALE)
    new_img = squared(img, desired_size)

#進行正規化(normalization)，常用除255或z-score
    m = np.mean(new_img)
    s = np.std(new_img)
    t = (new_img-m)/s
#    t=new_img/255

#三個channel可給予不同的處理手法
    all_data[i,:,:,0]=t
    all_data[i,:,:,1]=t
    all_data[i,:,:,2]=t
# Out:
# 100%|██████████| 1440/1440 [00:01<00:00, 1267.38it/s]

# %%
label=np.array(label)

# %% [markdown]
# ### 模型匯入與切分資料集

# %%
#以test_size的比例分訓練集和驗證集
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, Y_test = train_test_split(all_data, label, test_size=0.2, random_state=90)

# %%
#對類別資料作One-hot encoding
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(Y_test)

# %% [markdown]
# ## 建立AI模型

# %%
#撰寫模型
input_layer=tf.keras.layers.Input(shape=(desired_size,desired_size,3))

x=tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu')(input_layer)
x=tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu')(x)
x=tf.keras.layers.MaxPool2D()(x)

x=tf.keras.layers.Flatten()(x)
x=tf.keras.layers.Dense(32, activation='relu')(x)

output_layer=tf.keras.layers.Dense(num_classes, activation='softmax')(x)

# %%
model=tf.keras.models.Model(inputs=input_layer, outputs=output_layer)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 200, 200, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 198, 198, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 196, 196, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 98, 98, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 614656)            0
# _________________________________________________________________
# dense (Dense)                (None, 32)                19669024
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 19,707,942
# Trainable params: 19,707,942
# Non-trainable params: 0
# _________________________________________________________________

# %%
#data augmentation相關設定
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True)

# %% [markdown]
# ## 開始訓練

# %%
#告訴AI學習的方式
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[tf.keras.metrics.CategoricalAccuracy()])

# %%
#將訓練的模型置放於model_path下的model_name
model_name = 'NEU'

save_dir = os.path.join(os.getcwd(), 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
model_path = os.path.join(save_dir, model_name)

# %%
#設定模型存放方式(只存Validation表現最好的那一次)
checkpoint = tf.keras.callbacks.ModelCheckpoint(model_path, monitor = 'val_loss', save_best_only = True, verbose = 1)

#設定多久沒進步就停下來
earlystop = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 10, verbose = 1)

# %%
#開始訓練，順便把訓練過程存到model_history，方便後續畫圖
model_history=model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=50, 
                        steps_per_epoch=len(x_train)/32, validation_data=(x_test,y_test), callbacks=[earlystop, checkpoint])
# Out:
# Epoch 1/50
# 36/36 [==============================] - 12s 271ms/step - loss: 5.4385 - categorical_accuracy: 0.2396 - val_loss: 1.7104 - val_categorical_accuracy: 0.1701
#
# Epoch 00001: val_loss improved from inf to 1.71039, saving model to /home/robust5566/saved_models/cirfar10
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/cirfar10/assets
# Epoch 2/50
# 36/36 [==============================] - 7s 191ms/step - loss: 1.5876 - categorical_accuracy: 0.3056 - val_loss: 1.5761 - val_categorical_accuracy: 0.2882
#
# Epoch 00002: val_loss improved from 1.71039 to 1.57608, saving model to /home/robust5566/saved_models/cirfar10
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/cirfar10/assets
# Epoch 3/50
# 36/36 [==============================] - 7s 193ms/step - loss: 1.5207 - categorical_accuracy: 0.3550 - val_loss: 1.5426 - val_categorical_accuracy: 0.3438
#
# Epoch 00003: val_loss improved from 1.57608 to 1.54263, saving model to /home/robust5566/saved_models/cirfar10
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/cirfar10/assets
# Epoch 4/50
# 36/36 [==============================] - 7s 191ms/step - loss: 1.4218 - categorical_accuracy: 0.3984 - val_loss: 1.2785 - val_categorical_accuracy: 0.4549
#
# Epoch 00004: val_loss improved from 1.54263 to 1.27845, saving model to /home/robust5566/saved_models/cirfar10
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/cirfar10/assets
# Epoch 5/50
# 36/36 [==============================] - 7s 194ms/step - loss: 1.1413 - categorical_accuracy: 0.4905 - val_loss: 1.2234 - val_categorical_accuracy: 0.5278
#
# Epoch 00005: val_loss improved from 1.27845 to 1.22340, saving model to /home/robust5566/saved_models/cirfar10
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/cirfar10/assets
# Epoch 6/50
# 36/36 [==============================] - 7s 193ms/step - loss: 0.9331 - categorical_accuracy: 0.6059 - val_loss: 1.3063 - val_categorical_accuracy: 0.5903
#
# Epoch 00006: val_loss did not improve from 1.22340
# Epoch 7/50
# 36/36 [==============================] - 7s 194ms/step - loss: 0.9014 - categorical_accuracy: 0.6267 - val_loss: 1.5739 - val_categorical_accuracy: 0.5104
#
# Epoch 00007: val_loss did not improve from 1.22340
# Epoch 8/50
# 36/36 [==============================] - 7s 194ms/step - loss: 0.7889 - categorical_accuracy: 0.6762 - val_loss: 2.1827 - val_categorical_accuracy: 0.5104
#
# Epoch 00008: val_loss did not improve from 1.22340
# Epoch 9/50
# 36/36 [==============================] - 7s 194ms/step - loss: 0.7021 - categorical_accuracy: 0.7387 - val_loss: 0.8950 - val_categorical_accuracy: 0.7326
#
# Epoch 00009: val_loss improved from 1.22340 to 0.89499, saving model to /home/robust5566/saved_models/cirfar10
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/cirfar10/assets
# Epoch 10/50
# 36/36 [==============================] - 7s 193ms/step - loss: 0.6581 - categorical_accuracy: 0.7413 - val_loss: 1.8099 - val_categorical_accuracy: 0.6042
#
# Epoch 00010: val_loss did not improve from 0.89499
# Epoch 11/50
# 36/36 [==============================] - 7s 193ms/step - loss: 0.6693 - categorical_accuracy: 0.7378 - val_loss: 2.2519 - val_categorical_accuracy: 0.5104
#
# Epoch 00011: val_loss did not improve from 0.89499
# Epoch 12/50
# 36/36 [==============================] - 7s 192ms/step - loss: 0.6290 - categorical_accuracy: 0.7656 - val_loss: 1.4358 - val_categorical_accuracy: 0.6319
#
# Epoch 00012: val_loss did not improve from 0.89499
# Epoch 13/50
# 36/36 [==============================] - 7s 194ms/step - loss: 0.5100 - categorical_accuracy: 0.8003 - val_loss: 2.1187 - val_categorical_accuracy: 0.5278
#
# Epoch 00013: val_loss did not improve from 0.89499
# Epoch 14/50
# 36/36 [==============================] - 7s 192ms/step - loss: 0.5388 - categorical_accuracy: 0.7917 - val_loss: 1.3888 - val_categorical_accuracy: 0.6424
#
# Epoch 00014: val_loss did not improve from 0.89499
# Epoch 15/50
# 36/36 [==============================] - 7s 194ms/step - loss: 0.4330 - categorical_accuracy: 0.8438 - val_loss: 2.1545 - val_categorical_accuracy: 0.5035
#
# Epoch 00015: val_loss did not improve from 0.89499
# Epoch 16/50
# 36/36 [==============================] - 7s 192ms/step - loss: 0.4192 - categorical_accuracy: 0.8403 - val_loss: 2.0704 - val_categorical_accuracy: 0.5625
#
# Epoch 00016: val_loss did not improve from 0.89499
# Epoch 17/50
# 36/36 [==============================] - 7s 193ms/step - loss: 0.4072 - categorical_accuracy: 0.8568 - val_loss: 1.4486 - val_categorical_accuracy: 0.6354
#
# Epoch 00017: val_loss did not improve from 0.89499
# Epoch 18/50
# 36/36 [==============================] - 7s 194ms/step - loss: 0.3991 - categorical_accuracy: 0.8576 - val_loss: 1.5866 - val_categorical_accuracy: 0.6146
#
# Epoch 00018: val_loss did not improve from 0.89499
# Epoch 19/50
# 36/36 [==============================] - 7s 193ms/step - loss: 0.3616 - categorical_accuracy: 0.8802 - val_loss: 2.4288 - val_categorical_accuracy: 0.5660
#
# Epoch 00019: val_loss did not improve from 0.89499
# Epoch 00019: early stopping

# %% [markdown]
# ## 畫圖

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy'])

# %%
training_loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

training_acc = model_history.history['categorical_accuracy']
val_acc = model_history.history['val_categorical_accuracy']

# %%
#畫圖
plt.figure(figsize=(18, 7))
plt.subplot(121)
plt.plot(training_loss, label="training_loss")
plt.plot(val_loss, label="validation_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Learning Curve")
plt.legend(loc='best')

plt.subplot(122)
plt.plot(training_acc, label="training_acc")
plt.plot(val_acc, label="validation_acc")
plt.legend(loc='upper left')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy Curve")
plt.legend(loc='best')

plt.show()

# %% [markdown]
# ## 作預測

# %%
#載入訓練好的模型
model = tf.keras.models.load_model(model_path)

# %%
#使用AI模型作預測
pred=model.predict(x_test)

# %%
#將預測的機率轉換成類別
ans=np.argmax(pred, axis=-1)

# %%
#畫出混淆矩陣
from sklearn.metrics import confusion_matrix

cf_matrix = confusion_matrix(Y_test, ans)
print(cf_matrix)
# Out:
# [[37  3  2  1  1  5]
#  [10 31  0  0  1  1]
#  [ 0  0 44  0  0  0]
#  [ 0  1  0 45  0  0]
#  [12 23  0  6 19  0]
#  [ 0  4  0  7  0 35]]

# %%
#對混淆矩陣畫圖
import seaborn as sns
fig, ax = plt.subplots(figsize=(13,13))
sns.heatmap(cf_matrix, fmt='g', annot=True, annot_kws={"size":12})
# Out:
# <AxesSubplot:>

# %%
#計算統計指標
from sklearn.metrics import classification_report
report = classification_report(Y_test, ans)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.76      0.69        49
#            1       0.50      0.72      0.59        43
#            2       0.96      1.00      0.98        44
#            3       0.76      0.98      0.86        46
#            4       0.90      0.32      0.47        60
#            5       0.85      0.76      0.80        46
#
#     accuracy                           0.73       288
#    macro avg       0.77      0.76      0.73       288
# weighted avg       0.77      0.73      0.72       288

# %% [markdown]
# # 使用NEU-DET練習影像分類，模型設計調校

# %% [markdown]
# ### 匯入函式庫

# %%
#匯入函式庫，數值矩陣計算numpy，以及畫圖用的matplotlib
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

#匯入
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

# %%
import tensorflow as tf

# %%
#文件搜索的工具
import glob

#這是一個看迴圈進度條的小工具
from tqdm import tqdm 

#匯入電腦視覺的函式庫，作影像讀取和分析使用
import cv2

# %% [markdown]
# ### 讀入一張影像測試與檢視

# %%
#讀一張影像試試

path_name='NEU-DET/train/images/crazing/crazing_1.jpg'
# path_name='chest_xray/train/NORMAL/IM-0117-0001.jpeg'
img = cv2.imread(path_name,cv2.IMREAD_GRAYSCALE)

#cv2.IMREAD_GRAYSCALE 以灰階的格式來讀取圖片。預設值為cv2.IMREAD_COLOR(讀取 RGB 三個 channels)

#其他的讀取方式：(1)matplotlib、(2)PIL
#import matplotlib.image as mpimg
#img = mpimg.imread(path_name)

#from PIL import Image
#img = Image.open(path_name)

# %%
mpl.rcParams['figure.figsize'] = (12,12) #畫布尺寸

# %%
print('img (x_dim, y_dim) and type: ',img.shape, img.dtype)
plt.imshow(img, cmap='gray')
# Out:
# img (x_dim, y_dim) and type:  (200, 200) uint8

# %% [markdown]
# ### 定義訓練資料

# %%
#欲分類的lable與數量
labels_name = os.listdir('./NEU-DET/train/images/')
num_classes = len(labels_name)

# %%
labels_name
# Out:
# ['scratches',
#  'inclusion',
#  'rolled-in_scale',
#  'crazing',
#  'pitted_surface',
#  'patches']

# %%
num_classes
# Out:
# 6

# %%
#建立訓練資料所在的路徑位置與對應的label：(filelist, label)
#label為數字，0代表'NORMAL'、1代表'PNEUMONIA'
filelist = []
label = []
for i in labels_name:
    class_num = labels_name.index(i)
    pathfile = glob.glob('./NEU-DET/train/images/'+str(i)+'/*.jpg')
    
    for p in pathfile:
        filelist.append(p)
        label.append(class_num)

# %%
print('numbers of img:',len(filelist))
# Out:
# numbers of img: 1440

# %%
#影像縮放大小
desired_size = 200

# %%
#定義一個縮放影像(img)至指定大小(desired_size)的函數
#等比例縮小，其他地方補黑邊
def squared(img, desired_size):
    old_size = img.shape[:2]
    ratio = float(desired_size)/max(old_size)
    new_size = tuple([int(x*ratio) for x in old_size])
    img = cv2.resize(img, (new_size[1], new_size[0]))
    delta_w = desired_size - new_size[1]
    delta_h = desired_size - new_size[0]
    top, bottom = delta_h//2, delta_h-(delta_h//2)
    left, right = delta_w//2, delta_w-(delta_w//2)
    color = [0, 0, 0]
    new_img = cv2.copyMakeBorder(img, top, bottom, left, right, cv2.BORDER_CONSTANT,value=color)
    return new_img

# %% [markdown]
# ### 開始讀入影像

# %%
#先宣告一個指定大小的ndarray
all_data = np.zeros((len(filelist),desired_size,desired_size,3), dtype=np.float32)

# %%
#開始讀入影像
for i in tqdm(range(len(filelist))):
    img = cv2.imread(filelist[i], cv2.IMREAD_GRAYSCALE)
    new_img = squared(img, desired_size)

#進行正規化(normalization)，常用除255或z-score
    m = np.mean(new_img)
    s = np.std(new_img)
    t = (new_img-m)/s
#    t=new_img/255

#三個channel可給予不同的處理手法
    all_data[i,:,:,0]=t
    all_data[i,:,:,1]=t
    all_data[i,:,:,2]=t
# Out:
# 100%|██████████| 1440/1440 [00:10<00:00, 136.31it/s]

# %%
label=np.array(label)

# %% [markdown]
# ### 模型匯入與切分資料集

# %%
#以test_size的比例分訓練集和驗證集
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, Y_test = train_test_split(all_data, label, test_size=0.2, random_state=90)

# %%
#對類別資料作One-hot encoding
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(Y_test)

# %% [markdown]
# ## 建立AI模型

# %%
#撰寫模型
input_layer=tf.keras.layers.Input(shape=(desired_size,desired_size,3))

x=tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu')(input_layer)
x=tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu')(x)
x=tf.keras.layers.MaxPool2D()(x)

x=tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu')(x)
x=tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu')(x)
x=tf.keras.layers.MaxPool2D()(x)

x=tf.keras.layers.Flatten()(x)
x=tf.keras.layers.Dense(64, activation='relu')(x)
x=tf.keras.layers.Dropout(0.5)(x)

output_layer=tf.keras.layers.Dense(num_classes, activation='softmax')(x)

# %%
model=tf.keras.models.Model(inputs=input_layer, outputs=output_layer)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 200, 200, 3)]     0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 198, 198, 32)      896
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 196, 196, 32)      9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 98, 98, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 96, 96, 64)        18496
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 94, 94, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 47, 47, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 141376)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                9048128
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 9,114,086
# Trainable params: 9,114,086
# Non-trainable params: 0
# _________________________________________________________________

# %%
#data augmentation相關設定
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True)

# %% [markdown]
# ## 開始訓練

# %%
#告訴AI學習的方式
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, decay=1e-6),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[tf.keras.metrics.CategoricalAccuracy()])

# %%
#將訓練的模型置放於model_path下的model_name
model_name = 'NEU'

save_dir = os.path.join(os.getcwd(), 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
model_path = os.path.join(save_dir, model_name)

# %%
#設定模型存放方式(只存Validation表現最好的那一次)
checkpoint = tf.keras.callbacks.ModelCheckpoint(model_path, monitor = 'val_loss', save_best_only = True, verbose = 1)

#設定多久沒進步就停下來
earlystop = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 20, verbose = 1)

# %%
#開始訓練，順便把訓練過程存到model_history，方便後續畫圖
model_history=model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=70, 
                        steps_per_epoch=len(x_train)/32, validation_data=(x_test,y_test), callbacks=[earlystop, checkpoint])
# Out:
# Epoch 1/70
# 36/36 [==============================] - 10s 260ms/step - loss: 1.9410 - categorical_accuracy: 0.2274 - val_loss: 1.5781 - val_categorical_accuracy: 0.4479
#
# Epoch 00001: val_loss improved from inf to 1.57809, saving model to /home/robust5566/saved_models/NEU
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/NEU/assets
# Epoch 2/70
# 36/36 [==============================] - 7s 192ms/step - loss: 1.4921 - categorical_accuracy: 0.3620 - val_loss: 1.1313 - val_categorical_accuracy: 0.5972
#
# Epoch 00002: val_loss improved from 1.57809 to 1.13135, saving model to /home/robust5566/saved_models/NEU
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/NEU/assets
# Epoch 3/70
# 36/36 [==============================] - 7s 193ms/step - loss: 1.2510 - categorical_accuracy: 0.4505 - val_loss: 1.1667 - val_categorical_accuracy: 0.5590
#
# Epoch 00003: val_loss did not improve from 1.13135
# Epoch 4/70
# 36/36 [==============================] - 7s 192ms/step - loss: 1.1050 - categorical_accuracy: 0.5217 - val_loss: 1.3684 - val_categorical_accuracy: 0.4444
#
# Epoch 00004: val_loss did not improve from 1.13135
# Epoch 5/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.9512 - categorical_accuracy: 0.6155 - val_loss: 0.7321 - val_categorical_accuracy: 0.7361
#
# Epoch 00005: val_loss improved from 1.13135 to 0.73208, saving model to /home/robust5566/saved_models/NEU
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/NEU/assets
# Epoch 6/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.8112 - categorical_accuracy: 0.6606 - val_loss: 0.5526 - val_categorical_accuracy: 0.8299
#
# Epoch 00006: val_loss improved from 0.73208 to 0.55264, saving model to /home/robust5566/saved_models/NEU
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/NEU/assets
# Epoch 7/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.7786 - categorical_accuracy: 0.6901 - val_loss: 0.6372 - val_categorical_accuracy: 0.7847
#
# Epoch 00007: val_loss did not improve from 0.55264
# Epoch 8/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.7137 - categorical_accuracy: 0.7214 - val_loss: 1.2925 - val_categorical_accuracy: 0.6285
#
# Epoch 00008: val_loss did not improve from 0.55264
# Epoch 9/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.6339 - categorical_accuracy: 0.7526 - val_loss: 0.7063 - val_categorical_accuracy: 0.7326
#
# Epoch 00009: val_loss did not improve from 0.55264
# Epoch 10/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.5315 - categorical_accuracy: 0.7951 - val_loss: 0.4930 - val_categorical_accuracy: 0.8507
#
# Epoch 00010: val_loss improved from 0.55264 to 0.49297, saving model to /home/robust5566/saved_models/NEU
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/NEU/assets
# Epoch 11/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.4564 - categorical_accuracy: 0.8325 - val_loss: 0.3424 - val_categorical_accuracy: 0.8854
#
# Epoch 00011: val_loss improved from 0.49297 to 0.34237, saving model to /home/robust5566/saved_models/NEU
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/NEU/assets
# Epoch 12/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.6764 - categorical_accuracy: 0.7700 - val_loss: 1.2383 - val_categorical_accuracy: 0.6944
#
# Epoch 00012: val_loss did not improve from 0.34237
# Epoch 13/70
# 36/36 [==============================] - 7s 191ms/step - loss: 0.5243 - categorical_accuracy: 0.8177 - val_loss: 0.3395 - val_categorical_accuracy: 0.9062
#
# Epoch 00013: val_loss improved from 0.34237 to 0.33949, saving model to /home/robust5566/saved_models/NEU
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/NEU/assets
# Epoch 14/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.4163 - categorical_accuracy: 0.8377 - val_loss: 0.5885 - val_categorical_accuracy: 0.8333
#
# Epoch 00014: val_loss did not improve from 0.33949
# Epoch 15/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.3759 - categorical_accuracy: 0.8698 - val_loss: 0.3804 - val_categorical_accuracy: 0.8819
#
# Epoch 00015: val_loss did not improve from 0.33949
# Epoch 16/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.4852 - categorical_accuracy: 0.8351 - val_loss: 1.4312 - val_categorical_accuracy: 0.7118
#
# Epoch 00016: val_loss did not improve from 0.33949
# Epoch 17/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.3741 - categorical_accuracy: 0.8576 - val_loss: 3.5094 - val_categorical_accuracy: 0.6597
#
# Epoch 00017: val_loss did not improve from 0.33949
# Epoch 18/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.3343 - categorical_accuracy: 0.8915 - val_loss: 2.7635 - val_categorical_accuracy: 0.7083
#
# Epoch 00018: val_loss did not improve from 0.33949
# Epoch 19/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.3029 - categorical_accuracy: 0.9010 - val_loss: 3.7506 - val_categorical_accuracy: 0.6562
#
# Epoch 00019: val_loss did not improve from 0.33949
# Epoch 20/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.5301 - categorical_accuracy: 0.8151 - val_loss: 0.5810 - val_categorical_accuracy: 0.8229
#
# Epoch 00020: val_loss did not improve from 0.33949
# Epoch 21/70
# 36/36 [==============================] - 7s 191ms/step - loss: 0.3121 - categorical_accuracy: 0.8872 - val_loss: 0.6701 - val_categorical_accuracy: 0.7986
#
# Epoch 00021: val_loss did not improve from 0.33949
# Epoch 22/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.2563 - categorical_accuracy: 0.9106 - val_loss: 0.3261 - val_categorical_accuracy: 0.9028
#
# Epoch 00022: val_loss improved from 0.33949 to 0.32614, saving model to /home/robust5566/saved_models/NEU
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/NEU/assets
# Epoch 23/70
# 36/36 [==============================] - 7s 191ms/step - loss: 0.2624 - categorical_accuracy: 0.9097 - val_loss: 1.0902 - val_categorical_accuracy: 0.7465
#
# Epoch 00023: val_loss did not improve from 0.32614
# Epoch 24/70
# 36/36 [==============================] - 7s 190ms/step - loss: 0.2706 - categorical_accuracy: 0.9054 - val_loss: 0.2152 - val_categorical_accuracy: 0.9549
#
# Epoch 00024: val_loss improved from 0.32614 to 0.21523, saving model to /home/robust5566/saved_models/NEU
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/NEU/assets
# Epoch 25/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.2853 - categorical_accuracy: 0.9002 - val_loss: 1.0000 - val_categorical_accuracy: 0.7812
#
# Epoch 00025: val_loss did not improve from 0.21523
# Epoch 26/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.1901 - categorical_accuracy: 0.9418 - val_loss: 0.9433 - val_categorical_accuracy: 0.7743
#
# Epoch 00026: val_loss did not improve from 0.21523
# Epoch 27/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.1780 - categorical_accuracy: 0.9427 - val_loss: 1.9625 - val_categorical_accuracy: 0.7639
#
# Epoch 00027: val_loss did not improve from 0.21523
# Epoch 28/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.1490 - categorical_accuracy: 0.9514 - val_loss: 3.3843 - val_categorical_accuracy: 0.7049
#
# Epoch 00028: val_loss did not improve from 0.21523
# Epoch 29/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.1785 - categorical_accuracy: 0.9288 - val_loss: 1.4701 - val_categorical_accuracy: 0.7535
#
# Epoch 00029: val_loss did not improve from 0.21523
# Epoch 30/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.1907 - categorical_accuracy: 0.9366 - val_loss: 2.9653 - val_categorical_accuracy: 0.6736
#
# Epoch 00030: val_loss did not improve from 0.21523
# Epoch 31/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.1548 - categorical_accuracy: 0.9549 - val_loss: 0.0994 - val_categorical_accuracy: 0.9722
#
# Epoch 00031: val_loss improved from 0.21523 to 0.09942, saving model to /home/robust5566/saved_models/NEU
# INFO:tensorflow:Assets written to: /home/robust5566/saved_models/NEU/assets
# Epoch 32/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.1728 - categorical_accuracy: 0.9384 - val_loss: 0.7778 - val_categorical_accuracy: 0.8333
#
# Epoch 00032: val_loss did not improve from 0.09942
# Epoch 33/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.2109 - categorical_accuracy: 0.9262 - val_loss: 1.8563 - val_categorical_accuracy: 0.6910
#
# Epoch 00033: val_loss did not improve from 0.09942
# Epoch 34/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.1765 - categorical_accuracy: 0.9340 - val_loss: 2.2688 - val_categorical_accuracy: 0.7257
#
# Epoch 00034: val_loss did not improve from 0.09942
# Epoch 35/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.1382 - categorical_accuracy: 0.9514 - val_loss: 2.4673 - val_categorical_accuracy: 0.7361
#
# Epoch 00035: val_loss did not improve from 0.09942
# Epoch 36/70
# 36/36 [==============================] - 7s 191ms/step - loss: 0.1510 - categorical_accuracy: 0.9349 - val_loss: 2.6546 - val_categorical_accuracy: 0.7326
#
# Epoch 00036: val_loss did not improve from 0.09942
# Epoch 37/70
# 36/36 [==============================] - 7s 190ms/step - loss: 0.1418 - categorical_accuracy: 0.9497 - val_loss: 3.8628 - val_categorical_accuracy: 0.7014
#
# Epoch 00037: val_loss did not improve from 0.09942
# Epoch 38/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.1302 - categorical_accuracy: 0.9531 - val_loss: 7.3751 - val_categorical_accuracy: 0.6319
#
# Epoch 00038: val_loss did not improve from 0.09942
# Epoch 39/70
# 36/36 [==============================] - 7s 194ms/step - loss: 0.1745 - categorical_accuracy: 0.9444 - val_loss: 1.6088 - val_categorical_accuracy: 0.7326
#
# Epoch 00039: val_loss did not improve from 0.09942
# Epoch 40/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.1627 - categorical_accuracy: 0.9366 - val_loss: 0.9333 - val_categorical_accuracy: 0.8472
#
# Epoch 00040: val_loss did not improve from 0.09942
# Epoch 41/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.1287 - categorical_accuracy: 0.9583 - val_loss: 2.9004 - val_categorical_accuracy: 0.7431
#
# Epoch 00041: val_loss did not improve from 0.09942
# Epoch 42/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.1261 - categorical_accuracy: 0.9566 - val_loss: 1.2751 - val_categorical_accuracy: 0.7882
#
# Epoch 00042: val_loss did not improve from 0.09942
# Epoch 43/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.2221 - categorical_accuracy: 0.9332 - val_loss: 1.1419 - val_categorical_accuracy: 0.8090
#
# Epoch 00043: val_loss did not improve from 0.09942
# Epoch 44/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.1086 - categorical_accuracy: 0.9618 - val_loss: 1.0905 - val_categorical_accuracy: 0.7986
#
# Epoch 00044: val_loss did not improve from 0.09942
# Epoch 45/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.1447 - categorical_accuracy: 0.9479 - val_loss: 2.1644 - val_categorical_accuracy: 0.7292
#
# Epoch 00045: val_loss did not improve from 0.09942
# Epoch 46/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.1042 - categorical_accuracy: 0.9679 - val_loss: 1.5763 - val_categorical_accuracy: 0.7951
#
# Epoch 00046: val_loss did not improve from 0.09942
# Epoch 47/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0954 - categorical_accuracy: 0.9609 - val_loss: 3.2494 - val_categorical_accuracy: 0.7292
#
# Epoch 00047: val_loss did not improve from 0.09942
# Epoch 48/70
# 36/36 [==============================] - 7s 192ms/step - loss: 0.1274 - categorical_accuracy: 0.9583 - val_loss: 0.4660 - val_categorical_accuracy: 0.9028
#
# Epoch 00048: val_loss did not improve from 0.09942
# Epoch 49/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.1053 - categorical_accuracy: 0.9618 - val_loss: 1.7838 - val_categorical_accuracy: 0.7500
#
# Epoch 00049: val_loss did not improve from 0.09942
# Epoch 50/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.0938 - categorical_accuracy: 0.9627 - val_loss: 0.7423 - val_categorical_accuracy: 0.8715
#
# Epoch 00050: val_loss did not improve from 0.09942
# Epoch 51/70
# 36/36 [==============================] - 7s 193ms/step - loss: 0.1017 - categorical_accuracy: 0.9679 - val_loss: 0.2475 - val_categorical_accuracy: 0.9444
#
# Epoch 00051: val_loss did not improve from 0.09942
# Epoch 00051: early stopping

# %% [markdown]
# ## 畫圖

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy'])

# %%
training_loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

training_acc = model_history.history['categorical_accuracy']
val_acc = model_history.history['val_categorical_accuracy']

# %%
#畫圖
plt.figure(figsize=(18, 7))
plt.subplot(121)
plt.plot(training_loss, label="training_loss")
plt.plot(val_loss, label="validation_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Learning Curve")
plt.legend(loc='best')

plt.subplot(122)
plt.plot(training_acc, label="training_acc")
plt.plot(val_acc, label="validation_acc")
plt.legend(loc='upper left')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy Curve")
plt.legend(loc='best')

plt.show()

# %% [markdown]
# ## 作預測

# %%
#載入訓練好的模型
model = tf.keras.models.load_model(model_path)

# %%
#使用AI模型作預測
pred=model.predict(x_test)

# %%
#將預測的機率轉換成類別
ans=np.argmax(pred, axis=-1)

# %%
#畫出混淆矩陣
from sklearn.metrics import confusion_matrix

cf_matrix = confusion_matrix(Y_test, ans)
print(cf_matrix)
# Out:
# [[48  1  0  0  0  0]
#  [ 0 41  0  0  0  2]
#  [ 0  0 44  0  0  0]
#  [ 0  0  2 44  0  0]
#  [ 0  0  0  1 59  0]
#  [ 0  0  1  1  0 44]]

# %%
#對混淆矩陣畫圖
import seaborn as sns
fig, ax = plt.subplots(figsize=(13,13))
sns.heatmap(cf_matrix, fmt='g', annot=True, annot_kws={"size":12})
# Out:
# <AxesSubplot:>

# %%
#計算統計指標
from sklearn.metrics import classification_report
report = classification_report(Y_test, ans)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        49
#            1       0.98      0.95      0.96        43
#            2       0.94      1.00      0.97        44
#            3       0.96      0.96      0.96        46
#            4       1.00      0.98      0.99        60
#            5       0.96      0.96      0.96        46
#
#     accuracy                           0.97       288
#    macro avg       0.97      0.97      0.97       288
# weighted avg       0.97      0.97      0.97       288

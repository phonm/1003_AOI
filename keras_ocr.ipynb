# %%
# !pip install keras_ocr
# Out:
# Requirement already satisfied: keras_ocr in ./.local/lib/python3.8/site-packages (0.8.7)
# Requirement already satisfied: validators in ./.local/lib/python3.8/site-packages (from keras_ocr) (0.18.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from keras_ocr) (4.62.1)
# Requirement already satisfied: efficientnet==1.0.0 in ./.local/lib/python3.8/site-packages (from keras_ocr) (1.0.0)
# Requirement already satisfied: pyclipper in ./.local/lib/python3.8/site-packages (from keras_ocr) (1.3.0)
# Requirement already satisfied: imgaug in ./.local/lib/python3.8/site-packages (from keras_ocr) (0.4.0)
# Requirement already satisfied: shapely in ./.local/lib/python3.8/site-packages (from keras_ocr) (1.7.1)
# Requirement already satisfied: fonttools in ./.local/lib/python3.8/site-packages (from keras_ocr) (4.27.1)
# Requirement already satisfied: editdistance in ./.local/lib/python3.8/site-packages (from keras_ocr) (0.5.3)
# Requirement already satisfied: essential-generators in ./.local/lib/python3.8/site-packages (from keras_ocr) (1.0)
# Requirement already satisfied: scikit-image in ./.local/lib/python3.8/site-packages (from efficientnet==1.0.0->keras_ocr) (0.18.3)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.8/dist-packages (from efficientnet==1.0.0->keras_ocr) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.8/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.0.0->keras_ocr) (1.19.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.0.0->keras_ocr) (3.1.0)
# Requirement already satisfied: matplotlib in ./.local/lib/python3.8/site-packages (from imgaug->keras_ocr) (3.4.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from imgaug->keras_ocr) (1.15.0)
# Requirement already satisfied: imageio in ./.local/lib/python3.8/site-packages (from imgaug->keras_ocr) (2.9.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from imgaug->keras_ocr) (1.4.1)
# Requirement already satisfied: Pillow in ./.local/lib/python3.8/site-packages (from imgaug->keras_ocr) (8.2.0)
# Requirement already satisfied: opencv-python in ./.local/lib/python3.8/site-packages (from imgaug->keras_ocr) (4.5.3.56)
# Requirement already satisfied: tifffile>=2019.7.26 in ./.local/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (2021.8.30)
# Requirement already satisfied: networkx>=2.0 in ./.local/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (2.6.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in ./.local/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (1.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug->keras_ocr) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in ./.local/lib/python3.8/site-packages (from matplotlib->imgaug->keras_ocr) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->imgaug->keras_ocr) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.local/lib/python3.8/site-packages (from matplotlib->imgaug->keras_ocr) (1.3.2)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from validators->keras_ocr) (5.0.9)
# Hit:1 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libxext6 is already the newest version (2:1.3.4-0ubuntu1).
# libxext6 set to manually installed.
# The following additional packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-common
#   libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdrm2 libelf1
#   libfftw3-double3 libflac8 libflite1 libfontconfig1 libfreetype6 libfribidi0
#   libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgl1
#   libgl1-mesa-dri libglapi-mesa libglvnd0 libglx-mesa0 libglx0 libgme0
#   libgraphite2-3 libgsm1 libharfbuzz0b libice6 libiec61883-0 libigdgmm11
#   libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8 liblilv-0-0 libllvm12
#   libmp3lame0 libmpg123-0 libmysofa1 libnorm1 libopenal-data libopenal1
#   libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0 libpixman-1-0 libpng16-16
#   libpostproc55 libpulse0 libraw1394-11 librsvg2-2 librsvg2-common
#   librubberband2 libsamplerate0 libsdl2-2.0-0 libsensors-config libsensors5
#   libserd-0-0 libshine3 libslang2 libsnappy1v5 libsndfile1 libsndio7.0
#   libsodium23 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libusb-1.0-0 libva-drm2 libva-x11-2 libva2 libvdpau1
#   libvidstab1.1 libvorbisenc2 libvpx6 libvulkan1 libwavpack1
#   libwayland-client0 libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3
#   libx11-xcb1 libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 shared-mime-info
#   va-driver-all vdpau-driver-all x11-common xkb-data
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libbluray-bdj libfftw3-bin libfftw3-dev
#   jackd2 libportaudio2 opus-tools pciutils pulseaudio libraw1394-doc
#   librsvg2-bin lm-sensors serdi sndiod sordi speex opencl-icd libvdpau-va-gl1
#   nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
#   nvidia-legacy-304xx-vdpau-driver
# The following NEW packages will be installed:
#   ffmpeg fontconfig fontconfig-config fonts-dejavu-core i965-va-driver
#   intel-media-va-driver libaacs0 libaom0 libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavresample4
#   libavutil56 libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo-gobject2
#   libcairo2 libcdio-cdda2 libcdio-paranoia2 libcdio18 libchromaprint1
#   libcodec2-0.9 libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-common
#   libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdrm2 libelf1
#   libfftw3-double3 libflac8 libflite1 libfontconfig1 libfreetype6 libfribidi0
#   libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgl1
#   libgl1-mesa-dri libglapi-mesa libglvnd0 libglx-mesa0 libglx0 libgme0
#   libgraphite2-3 libgsm1 libharfbuzz0b libice6 libiec61883-0 libigdgmm11
#   libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8 liblilv-0-0 libllvm12
#   libmp3lame0 libmpg123-0 libmysofa1 libnorm1 libopenal-data libopenal1
#   libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpciaccess0 libpgm-5.2-0 libpixman-1-0 libpng16-16
#   libpostproc55 libpulse0 libraw1394-11 librsvg2-2 librsvg2-common
#   librubberband2 libsamplerate0 libsdl2-2.0-0 libsensors-config libsensors5
#   libserd-0-0 libshine3 libslang2 libsm6 libsnappy1v5 libsndfile1 libsndio7.0
#   libsodium23 libsord-0-0 libsoxr0 libspeex1 libsratom-0-0 libssh-gcrypt-4
#   libswresample3 libswscale5 libthai-data libthai0 libtheora0 libtiff5
#   libtwolame0 libusb-1.0-0 libva-drm2 libva-x11-2 libva2 libvdpau1
#   libvidstab1.1 libvorbisenc2 libvpx6 libvulkan1 libwavpack1
#   libwayland-client0 libwayland-cursor0 libwayland-egl1 libwebp6 libwebpmux3
#   libx11-xcb1 libx264-155 libx265-179 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcursor1 libxfixes3 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1 libxv1
#   libxvidcore4 libxxf86vm1 libzmq5 libzvbi-common libzvbi0 mesa-va-drivers
#   mesa-vdpau-drivers mesa-vulkan-drivers ocl-icd-libopencl1 shared-mime-info
#   va-driver-all vdpau-driver-all x11-common xkb-data
# 0 upgraded, 163 newly installed, 0 to remove and 28 not upgraded.
# Need to get 93.0 MB of archives.
# After this operation, 700 MB of additional disk space will be used.
# Do you want to continue? [Y/n] ^C

# %% [raw]
# 如果執行下方程式碼有問題，到 terminal 輸入下方指令
# sudo apt-get update
# sudo apt-get install ffmpeg libsm6 libxext6
# 安裝完成後重整本檔案，然後才執行下方程式碼

# %%
import matplotlib.pyplot as plt
import keras_ocr
# Out:
# 2021-10-02 16:37:47.088745: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /home/robust5566/.keras-ocr/craft_mlt_25k.h5
# 2021-10-02 16:37:52.728920: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcuda.so.1
# 2021-10-02 16:37:52.839414: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1734] Found device 0 with properties:
# pciBusID: 0000:1c:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-10-02 16:37:52.839486: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-10-02 16:37:52.845927: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcublas.so.11
# 2021-10-02 16:37:52.846049: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcublasLt.so.11
# 2021-10-02 16:37:52.848775: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcufft.so.10
# 2021-10-02 16:37:52.849206: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcurand.so.10
# 2021-10-02 16:37:52.850144: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcutensor.so.1
# 2021-10-02 16:37:52.850822: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcusolver.so.11
# 2021-10-02 16:37:52.851888: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcusparse.so.11
# 2021-10-02 16:37:52.852075: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudnn.so.8
# 2021-10-02 16:37:52.855212: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1872] Adding visible gpu devices: 0
# 2021-10-02 16:37:52.858193: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1734] Found device 0 with properties:
# pciBusID: 0000:1c:00.0 name: Tesla V100-SXM2-32GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 31.75GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-10-02 16:37:52.861122: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1872] Adding visible gpu devices: 0
# 2021-10-02 16:37:52.861198: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-10-02 16:37:53.437270: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-10-02 16:37:53.437309: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-10-02 16:37:53.437320: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2021-10-02 16:37:53.442010: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 31001 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:1c:00.0, compute capability: 7.0)
# 2021-10-02 16:37:53.442908: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 4. Tune using inter_op_parallelism_threads for best performance.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Looking for /home/robust5566/.keras-ocr/crnn_kurapan.h5

# %%
# Get a set of three example images
images = [
    keras_ocr.tools.read(url) for url in [
        'https://upload.wikimedia.org/wikipedia/commons/b/bd/Army_Reserves_Recruitment_Banner_MOD_45156284.jpg',
        'https://upload.wikimedia.org/wikipedia/commons/b/b4/EUBanana-500x112.jpg'
    ]
]

# Each list of predictions in prediction_groups is a list of
# (word, box) tuples.
prediction_groups = pipeline.recognize(images)

# Plot the predictions
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
# Out:
# 2021-10-02 16:37:56.937394: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-10-02 16:37:56.937913: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 3000000000 Hz
# 2021-10-02 16:37:56.938838: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:56.938853: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:56.938873: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:56.938879: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:56.944226: W tensorflow/compiler/jit/mark_for_compilation_pass.cc:1851] (One-time warning): Not using XLA:CPU for cluster because envvar TF_XLA_FLAGS=--tf_xla_cpu_global_jit was not set.  If you want XLA:CPU, either set that envvar, or use experimental_jit_scope to enable XLA:CPU.  To confirm that XLA is active, pass --vmodule=xla_compilation_cache=1 (as a proper command-line flag, not via TF_XLA_FLAGS) or set the envvar XLA_FLAGS=--xla_hlo_profile.
# 2021-10-02 16:37:56.950571: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:56.950608: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:56.950623: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:56.950630: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:56.961546: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:56.961591: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:56.961607: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:56.961615: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:57.179908: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:57.179956: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:57.179972: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:57.179979: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:57.348722: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f238440c590 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-10-02 16:37:57.348772: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2021-10-02 16:37:57.356255: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:57.356309: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:57.356340: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:57.356346: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:37:57.398727: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudnn.so.8
# 2021-10-02 16:37:57.962221: I tensorflow/stream_executor/cuda/cuda_dnn.cc:380] Loaded cuDNN version 8202
# 2021-10-02 16:37:58.580108: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcublas.so.11
# 2021-10-02 16:37:59.072244: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcublasLt.so.11
# 2021-10-02 16:38:00.869759: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:00.869810: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:00.869832: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:00.869843: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:00.928925: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:00.928969: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:00.928987: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:00.928996: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:00.989475: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:00.989549: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:00.989584: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:00.989600: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:01.343308: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:01.343353: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:01.343372: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:01.343380: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:01.351142: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:01.351184: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:01.351202: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:01.351209: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:01.363251: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:01.363295: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:01.363311: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:01.363318: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.235717: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.235767: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.235784: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.235791: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.548545: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.548592: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.548606: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.548613: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.746500: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.746547: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.746563: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.746570: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.764971: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.765015: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.765032: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.765039: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.765284: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.765309: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.765322: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.765329: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.808448: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.808499: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.808517: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:02.808524: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.024568: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.024612: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.024626: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.024633: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.030151: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.030187: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.030201: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.030207: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.045494: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.045540: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.045556: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.045562: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.045566: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.045593: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.045611: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.045619: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.059791: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.059827: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.059840: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.059846: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.070492: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.070538: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.070553: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.070559: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.084469: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.084513: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.084532: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:03.084539: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# /home/robust5566/.local/lib/python3.8/site-packages/keras_ocr/tools.py:156: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax.annotate(s=text,

# %%
images =[    keras_ocr.tools.read(path) for path in [
    './data/Recipe_2_194800378_20200727 041103.jpg',
'./data/ocr02.jpg',
'./data/ocr02-1.jpg',
'./data/ocr02-2.jpg']]

# %%
prediction_groups = pipeline.recognize(images)
# Out:
# 2021-10-02 16:38:19.616320: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.616357: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.616375: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.616381: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.625186: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.625227: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.625244: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.625251: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.636877: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.636920: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.636935: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.636942: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.823924: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.823962: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.823977: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:19.823983: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:20.014473: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:20.014553: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:20.014567: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:20.014573: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.033198: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.033239: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.033253: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.033259: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.149061: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.149131: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.149172: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.149190: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.247854: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.247898: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.247918: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.247928: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.632125: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.632161: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.632178: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.632184: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.639176: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.639209: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.639223: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.639230: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.648549: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.648585: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.648600: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.648606: W tensorflow/core/grappler/optimizers/meta_optimizer.cc:153] TF_ENABLE_AUTO_MIXED_PRECISION has no effect.
# 2021-10-02 16:38:23.792149: I tensorflow/compiler/jit/xla_compilation_cache.cc:342] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %%
# Plot the predictions
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
# Out:
# /home/robust5566/.local/lib/python3.8/site-packages/keras_ocr/tools.py:156: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   ax.annotate(s=text,
